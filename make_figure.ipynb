# %%
import sys
import numpy as np
fname="fig"
path="/".join(np.array(sys.executable.split("/"))[:-1])

# %%
# %%bash -s $fname $path
# cat<<EOF >$1.tex
# \documentclass{article}
# \usepackage[paperheight=272mm,paperwidth=210mm]{geometry}
# \geometry{left=5mm,right=5mm,top=5mm,bottom=5mm,}
#
# \usepackage[labelfont=bf]{caption}
# \usepackage[rgb]{xcolor}
# \usepackage{fontspec}
# \usepackage[utf8]{inputenc}
# \usepackage[T1]{fontenc}
# \usepackage{graphbox,graphicx}
# \usepackage{adjustbox}
#
# \begin{document}
# \setmainfont{Arial}
#
# \noindent
# \normalsize
#
# \fontsize{10pt}{10pt}\selectfont
#
#
# \raggedright \begin{minipage}[t]{.25\textwidth}
# \raggedright \textbf{a} published ENS data
# \includegraphics[width=\textwidth]{ENS_15/figures/ens_annot.pdf}
# \end{minipage}\hfill
# \begin{minipage}[t]{.25\textwidth}
# \raggedright \textbf{b} selection of early genes
# \includegraphics[width=\textwidth]{ENS_15/figures/early_pseudotime.pdf}
# \end{minipage}\hfill
# \begin{minipage}[t]{.24\textwidth}
# \raggedright \textbf{c} co-activation of modules
# \includegraphics[width=\textwidth]{ENS_15/figures/modulesupreg_early.pdf}
# \end{minipage}\hfill
# \begin{minipage}[t]{.26\textwidth}
# \raggedright \textbf{d} example of early genes
# \includegraphics[width=\textwidth]{ENS_15/figures/early_trends.pdf}
#
# \end{minipage}\hfill
#
# \raggedright \textbf{e} repulsion of early gene modules prior bifurcation
# \includegraphics[width=\textwidth]{ENS_15/figures/slide_corsEN1_EN2.pdf}
#
#
# \raggedright \begin{minipage}[t]{.24\textwidth}
# \raggedright\textbf{f} published hippocampus data
# \includegraphics[width=\textwidth]{Hippocampus/figures/hippocampus_annot.pdf}
# \end{minipage}\hfill
# \begin{minipage}[t]{.24\textwidth}
# \raggedright \textbf{g} selection of early genes
# \includegraphics[width=\textwidth]{Hippocampus/figures/early_pseudotime.pdf}
# \end{minipage}\hfill
# \begin{minipage}[t]{.24\textwidth}
# \raggedright \textbf{h} co-activation of modules
# \includegraphics[width=\textwidth]{Hippocampus/figures/upreg_early.pdf}
# \end{minipage}\hfill
# \begin{minipage}[t]{.26\textwidth}
# \raggedright \textbf{i} example of early genes
# \includegraphics[width=\textwidth]{Hippocampus/figures/early_trends.pdf}
#
# \end{minipage}\hfill
#
# \raggedright \textbf{j} repulsion of early gene modules prior bifurcation
# \includegraphics[width=\textwidth]{Hippocampus/figures/slide_corsCA_vs_Granule.pdf}
#
#
# \clearpage
# EOF
# echo "\end{document}" >> $1.tex
#
# $2/tectonic -c minimal $1.tex
#
# $2/identify $1.pdf
#
# $2/convert -flatten -density 300 $1.pdf $1.jpg
# Out:
# fig.pdf PDF 612x792 612x792+0+0 16-bit sRGB 3545B 0.000u 0:00.000

# %%
from IPython.display import Image
Image(filename=f'{fname}.jpg')
